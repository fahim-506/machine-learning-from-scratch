# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('student_clustering.csv')
print('The shape of data is ',df.shape)
df.head()
# Out:
# The shape of data is  (200, 2)
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110
