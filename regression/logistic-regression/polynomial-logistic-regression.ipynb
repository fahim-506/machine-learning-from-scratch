# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Ushape.csv')

# %%
df.head()
# Out:
#         X       Y  class
# 0  0.0316  0.9870    0.0
# 1  2.1200 -0.0462    1.0
# 2  0.8820 -0.0758    0.0
# 3 -0.0551 -0.0373    1.0
# 4  0.8300 -0.5390    1.0

# %%
X = df.iloc[:,0:2].values
y = df.iloc[:,-1].values

# %%
plt.scatter(X[:,0],X[:,1],c=y)
